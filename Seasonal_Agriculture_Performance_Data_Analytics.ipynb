# %% [markdown]
# # Seasonal Agriculture Performance Analysis
#
# ## Major Data Analytics Project
#
# **Domain:** Agriculture
#
# **Project Theme:** Seasonal Agriculture Performance Analysis
#
# **Tools:** Python, Pandas, NumPy, Matplotlib, Seaborn
#
# ### Project Goal
#
# Investigate how agricultural performance varies across seasons and identify meaningful patterns, trends, relationships and differences.

# %% [markdown]
# # 1. Problem Statement
#
# Agricultural activities are influenced by seasonal variations in environmental conditions, farming practices, resource availability and economic conditions. As a result, agricultural performance may differ from one season to another.
#
# The objective of this project is to analyze the given agricultural dataset and investigate seasonal differences in agricultural performance by identifying meaningful patterns, trends, relationships and variations within the available data.
#
# The problem is to understand how agricultural performance changes across seasons and what patterns can be observed in different seasonal conditions.
#
# The analysis will focus on examining seasonal differences in agricultural outcomes, environmental conditions, resource usage and economic performance.

# %% [markdown]
# # 2. Project Objectives
#
# The primary objective of this project is to analyze agricultural data from different seasons and identify meaningful patterns, trends, relationships and differences in agricultural performance.
#
# The specific objectives of this project are:
#
# - To explore and understand the structure and characteristics of the agricultural dataset.
# - To clean and prepare the data for analysis.
# - To examine how agricultural performance varies across seasons.
# - To identify important seasonal patterns and trends.
# - To investigate relationships between seasonal conditions and agricultural outcomes.
# - To compare relevant groups within different seasons.
# - To identify significant differences or unusual patterns.
# - To apply appropriate statistical and visualization techniques.
# - To interpret findings based on evidence from the dataset.
# - To develop meaningful conclusions and data-driven recommendations.

# %% [markdown]
# # 3. Dataset Description
#
# ## 3.1 Dataset Name
#
# **Dataset:** Seasonal Agriculture Performance Dataset
#
# **File Format:** CSV
#
# **File Name:** seasonal_agriculture_performance_dataset.csv
#
# ## 3.2 Dataset Overview
#
# The dataset contains information related to agricultural activities carried out across different seasons, geographical areas and farming conditions.
#
# It includes information about environmental conditions, farming practices, crop production, resource usage and economic performance.
#
# The dataset will be used to analyze seasonal differences and identify meaningful patterns, trends, relationships and variations in agricultural performance.
#
# ## 3.3 Main Categories of Variables
#
# The dataset includes variables related to:
#
# - **Seasonal Information:** Different agricultural seasons.
# - **Geographical Information:** States and other geographical areas.
# - **Crop Information:** Different crops and agricultural activities.
# - **Environmental Conditions:** Rainfall, temperature, humidity and sunlight.
# - **Soil Conditions:** Soil moisture and other soil-related characteristics.
# - **Farming Practices:** Irrigation methods, fertilizer usage and pesticide usage.
# - **Production:** Crop yield and total production.
# - **Economic Performance:** Market price, total cost, revenue and profit.
# - **Resource Usage:** Water consumption and water efficiency.
#
# ## 3.4 Purpose of Using the Dataset
#
# The dataset is used to investigate how agricultural performance varies across seasons and to understand the relationships between seasonal conditions, resource usage and agricultural outcomes.

# %%
#Import Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns",None)
pd.set_option("display.float_format",lambda x: f"{x:,.2f}")

# %%
file_path ="/content/seasonal_agriculture_performance_dataset.csv"
df = pd.read_csv(file_path)
print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %% [markdown]
# **4. Initial Data Understanding**

# %%
#Dataset shape

print("Number of rows:" ,df.shape[0])
print("Number of columns:" ,df.shape[1])
# Out:
# Number of rows: 4000
# Number of columns: 28

# %%
#Top 5 rows
df.head(5)
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0       486.40              24.30         69.10                5.80     7.14
# 1       855.40              25.70         78.40                5.10     5.20
# 2       455.60              23.90         56.40               10.30     5.82
# 3       753.20              29.70         65.20                6.30     5.98
# 4       101.60              34.10         55.20                6.50     6.90
#
# ...

# %%
#Bottom 5 rows
df.tail(5)
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995       865.40              27.30         51.40                6.30
# 3996       947.50              29.20         85.50                6.10
# 3997        80.00              35.40         68.50                8.60
# 3998       475.00              28.20         61.70                6.40
# 3999       984.30              25.80         77.20                5.90
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
#Random sample of records
df.sample(5, random_state =42)
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 555   SF10556  Andhra Pradesh    Nashik  Chilli    Rabi                7.94
# 3491  SF13492          Punjab  Warangal   Wheat  Kharif               12.44
# 527   SF10528     Maharashtra    Indore  Cotton  Kharif                6.35
# 3925  SF13926  Madhya Pradesh    Nashik   Wheat    Rabi               12.52
# 2989  SF12990         Gujarat    Rajkot  Chilli    Rabi               13.98
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 555        456.80              25.30         47.70                7.60
# 3491       601.90              27.20         60.20                8.30
# 527      1,213.70              26.30         73.60                7.10
# 3925       374.00              17.90         59.70                9.40
# 2989       197.80              19.00         55.80                9.20
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
#Column names

print(df.columns.tolist())
# Out:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
#Data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %% [markdown]
# **5. Data Quality Analysis**

# %%
#Numerical summary statistics
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count            4,000.00     3,952.00           4,000.00      4,000.00
# mean                 7.89       601.15              26.82         63.21
# std                  4.22       288.93               3.82         11.96
# min                  0.50        80.00              16.20         25.00
# 25%                  4.26       370.20              23.90         54.77
# 50%                  7.89       582.00              26.90         63.00
# 75%                 11.65       834.95              29.60         71.90
# max                 15.00     1,395.20              39.70         95.00
#
#        Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count            4,000.00 4,000.00           3,960.00        4,000.00
# mean                 7.32     6.70              26.51          120.25
# std                  1.12     0.64               6.71           31.22
# ...

# %%
#categorical summary

df.describe(include="object")
# Out:
#         Farm_ID           State  District  Crop  Season Irrigation_Method
# count      4000            4000      4000  4000    4000              4000
# unique     4000               8        10     8       3                 4
# top     SF13984  Andhra Pradesh  Ludhiana  Rice  Kharif             Flood
# freq          1             529       427   690    1779              1310

# %%
# Check missing values in the dataset

missing = df.isnull().sum().sort_values(ascending=False)

missing_percentage = (df.isnull().mean() * 100).sort_values(ascending=False)

missing_summary = pd.DataFrame({
    "Missing_Count": missing,
    "Missing_Percentage": missing_percentage.round(2)
})

# Display only columns that contain missing values
missing_summary[missing_summary["Missing_Count"] > 0]
# Out:
#                    Missing_Count  Missing_Percentage
# Rainfall_mm                   48                1.20
# Soil_Moisture_pct             40                1.00
# Yield_Tonnes_Ha               32                0.80

# %%
#Visualize missing values


plt.figure(figsize=(12, 5))

missing_plot = missing[missing > 0]

if len(missing_plot) > 0:
    sns.barplot(x=missing_plot.index, y=missing_plot.values)

    plt.xticks(rotation=60, ha="right")
    plt.ylabel("Number of Missing Values")
    plt.xlabel("Column")
    plt.title("Missing Values by Column")
    plt.tight_layout()
    plt.show()

else:
    print("No missing values found.")

# %%
# Duplicate records

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
# Remove duplicate rows

df = df.drop_duplicates()

print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Dataset shape after removing duplicates: (4000, 28)

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
# Check unique values for categorical columns

categorical_columns = df.select_dtypes(include="object").columns

for col in categorical_columns:
    print(f"\n{col}:")
    print(df[col].unique())
    print("Number of unique values:", df[col].nunique())
# Out:
# Farm_ID:
# ['SF10001' 'SF10002' 'SF10003' ... 'SF13998' 'SF13999' 'SF14000']
# Number of unique values: 4000
#
# State:
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
# Number of unique values: 8
#
# District:
# ['Rajkot' 'Nalgonda' 'Warangal' 'Indore' 'Ludhiana' 'Raichur' 'Guntur'
#  'Krishna' 'Nashik' 'Erode']
# Number of unique values: 10
#
# Crop:
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
# Number of unique values: 8
#
# Season:
# ['Kharif' 'Rabi' 'Zaid']
# Number of unique values: 3
#
# Irrigation_Method:
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']
# Number of unique values: 4

# %%
#Check missing values after duplicate removal

df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Rainfall_mm           48
# Soil_Moisture_pct     40
# Yield_Tonnes_Ha       32
# Farm_ID                0
# Crop                   0
# District               0
# Farm_Area_Hectares     0
# Season                 0
# Avg_Temperature_C      0
# Humidity_pct           0
# dtype: int64

# %% [markdown]
# # 4. Missing Value Treatment
#
# Missing values can affect the accuracy and reliability of data analysis. Therefore, missing values should be examined and treated using an appropriate strategy based on the nature of each variable.
#
# Possible approaches include:
#
# - Remove records only when justified.
# - Fill numerical values using an appropriate statistic when appropriate.
# - Fill categorical values using a suitable category or method.
# - Clearly document why the chosen approach is reasonable.
#
# The missing-value treatment strategy should be selected after examining the dataset and understanding the nature of the variables.

# %%
# Example: median imputation for numerical columns
# Students should review missingness before deciding whether to use this approach.

numeric_columns = df.select_dtypes(include=np.number).columns

for col in numeric_columns:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].median())

print("Remaining missing values:", df.isnull().sum().sum())
# Out:
# Remaining missing values: 0

# %% [markdown]
# **6. Feature/Variable Review**
#
# - Identifier variables
# - Categorical variables
# - Numerical variables
# - Environmental variables
# - Operational variables
# - Production/performance variables
# - Economic variables

# %%
# Identify numerical and categorical columns

numeric_columns = df.select_dtypes(include=np.number).columns.tolist()
categorical_columns = df.select_dtypes(include="object").columns.tolist()

print("Numerical columns:")
print(numeric_columns)

print("\nCategorical columns:")
print(categorical_columns)
# Out:
# Numerical columns:
# ['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']
#
# Categorical columns:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method']

# %%
# Descriptive statistics

stats = df[numeric_columns].describe().T

stats["range"] = stats["max"] - stats["min"]
stats["IQR"] = stats["75%"] - stats["25%"]

stats
# Out:
#                                  count       mean        std           min  \
# Farm_Area_Hectares            4,000.00       7.89       4.22          0.50
# Rainfall_mm                   4,000.00     600.92     287.19         80.00
# Avg_Temperature_C             4,000.00      26.82       3.82         16.20
# Humidity_pct                  4,000.00      63.21      11.96         25.00
# Sunlight_Hours_Day            4,000.00       7.32       1.12          3.50
# Soil_pH                       4,000.00       6.70       0.64          5.20
# Soil_Moisture_pct             4,000.00      26.51       6.68          8.00
# Nitrogen_kg_ha                4,000.00     120.25      31.22         40.00
# Phosphorus_kg_ha              4,000.00      57.78      17.02         15.00
# Potassium_kg_ha               4,000.00     104.76      27.74         30.00
# Fertilizer_kg_ha              4,000.00     186.04      60.26         40.00
# ...

# %%
# Mean, median and standard deviation

statistical_summary = pd.DataFrame({
    "Mean": df[numeric_columns].mean(),
    "Median": df[numeric_columns].median(),
    "Std_Dev": df[numeric_columns].std(),
    "Min": df[numeric_columns].min(),
    "Max": df[numeric_columns].max()
})

statistical_summary
# Out:
#                                     Mean     Median    Std_Dev           Min  \
# Farm_Area_Hectares                  7.89       7.89       4.22          0.50
# Rainfall_mm                       600.92     582.00     287.19         80.00
# Avg_Temperature_C                  26.82      26.90       3.82         16.20
# Humidity_pct                       63.21      63.00      11.96         25.00
# Sunlight_Hours_Day                  7.32       7.30       1.12          3.50
# Soil_pH                             6.70       6.69       0.64          5.20
# Soil_Moisture_pct                  26.51      26.40       6.68          8.00
# Nitrogen_kg_ha                    120.25     120.10      31.22         40.00
# Phosphorus_kg_ha                   57.78      57.50      17.02         15.00
# Potassium_kg_ha                   104.76     105.10      27.74         30.00
# Fertilizer_kg_ha                  186.04     186.25      60.26         40.00
# ...

# %%
# Seasonal descriptive summary

season_summary = df.groupby("Season")[numeric_columns].agg(
    ["mean", "median", "std"]
)

season_summary
# Out:
#        Farm_Area_Hectares             Rainfall_mm                \
#                      mean median  std        mean median    std
# Season
# Kharif               7.94   8.18 4.28      849.20 853.10 183.69
# Rabi                 7.75   7.68 4.18      437.62 432.20 175.35
# Zaid                 8.09   8.09 4.16      304.65 288.20 157.24
#
#        Avg_Temperature_C             Humidity_pct              \
#                     mean median  std         mean median  std
# Season
# Kharif             28.45  28.50 2.51        71.81  71.90 8.86
# Rabi               23.49  23.50 2.46        57.89  58.10 9.00
# Zaid               31.04  31.00 2.55        52.01  52.35 9.05
#
#        Sunlight_Hours_Day             Soil_pH             Soil_Moisture_pct  \
#                      mean median  std    mean median  std              mean
# Season
# Kharif               6.79   6.80 0.98    6.73   6.73 0.64             31.15
# ...

# %% [markdown]
# # 8. Univariate Analysis
#
# Univariate analysis is used to study one variable at a time and understand its distribution, frequency, and variation.
#
# The following variables will be analyzed:
#
# 1. Season Distribution
# 2. Crop Distribution
# 3. State Distribution
# 4. Irrigation Method Distribution
# 5. Humidity Distribution
# 6. Rainfall Distribution
# 7. Crop Yield Distribution
# 8. Farm Profit Distribution
#
# Create and interpret suitable plots for:
#
# - Important categorical variables
# - Important numerical variables
# - Seasonal distribution
# - Production/performance distributions
# - Economic distributions
#
# The plots will help identify patterns, frequencies, distributions, and variations in the agricultural dataset.

# %%
# Univariate Analysis: Season distribution

plt.figure(figsize=(7, 5))

sns.countplot(data=df, x="Season")

plt.title("Distribution of Records by Season")
plt.xlabel("Season")
plt.ylabel("Number of Records")

plt.tight_layout()
plt.show()

# %%
# 2. Crop Distribution

plt.figure(figsize=(10, 5))
sns.countplot(
    data=df,
    y="Crop",
    order=df["Crop"].value_counts().index
)

plt.title("Distribution of Crops")
plt.xlabel("Number of Records")
plt.ylabel("Crop")

plt.tight_layout()
plt.show()

# %%
# 3. State Distribution

plt.figure(figsize=(10, 6))
sns.countplot(
    data=df,
    y="State",
    order=df["State"].value_counts().index
)

plt.title("Distribution of Records by State")
plt.xlabel("Number of Records")
plt.ylabel("State")

plt.tight_layout()
plt.show()

# %%
# 4. Irrigation Method Distribution

plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x="Irrigation_Method",
    order=df["Irrigation_Method"].value_counts().index
)

plt.title("Distribution of Irrigation Methods")
plt.xlabel("Irrigation Method")
plt.ylabel("Number of Records")
plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# %%
# 5. Humidity Distribution

plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="Humidity_pct", kde=True)

plt.title("Distribution of Humidity")
plt.xlabel("Humidity (%)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# 6. Rainfall Distribution

plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="Rainfall_mm", kde=True)

plt.title("Distribution of Rainfall")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# 7. Crop Yield Distribution

plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="Yield_Tonnes_Ha", kde=True)
plt.title("Distribution of Crop Yield")
plt.xlabel("Yield (tonnes/ha)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# 8. Farm Profit Distribution

plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="Profit_INR", kde=True)

plt.title("Distribution of Farm Profit")
plt.xlabel("Profit (INR)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Outlier Analysis
#
# Investigate potential outliers using statistical and visual methods.
#
# Outliers should not be automatically deleted. Each extreme value should be evaluated to determine whether it is:
#
# - A data-entry problem.
# - A legitimate observation.
# - Something requiring further investigation.

# %%
# Univariate: Season distribution (Pie Chart)

plt.figure(figsize=(7, 7))

df["Season"].value_counts().plot.pie(
    autopct="%.1f%%",
    startangle=90,
    cmap="viridis"
)

plt.title("Distribution of Records by Season")
plt.ylabel("")  # Hide the default 'Season' label on the y-axis

plt.tight_layout()
plt.show()

# %%
# IQR-based outlier summary for numerical columns

outlier_summary = []

for col in numeric_columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    count = ((df[col] < lower) | (df[col] > upper)).sum()

    outlier_summary.append({
        "Column": col,
        "Lower_Bound": lower,
        "Upper_Bound": upper,
        "Outlier_Count": count,
        "Outlier_Percentage": round((count / len(df)) * 100, 2)
    })

outlier_summary = pd.DataFrame(outlier_summary)

outlier_summary
# Out:
#                            Column  Lower_Bound  Upper_Bound  Outlier_Count  \
# 0              Farm_Area_Hectares        -6.83        22.73              0
# 1                     Rainfall_mm      -319.02     1,522.57              0
# 2               Avg_Temperature_C        15.35        38.15              2
# 3                    Humidity_pct        29.09        97.59              6
# 4              Sunlight_Hours_Day         4.35        10.35             26
# 5                         Soil_pH         4.94         8.46              0
# 6               Soil_Moisture_pct         7.70        45.30              5
# 7                  Nitrogen_kg_ha        34.41       205.31             10
# 8                Phosphorus_kg_ha        11.40       104.20             16
# 9                 Potassium_kg_ha        30.10       179.70             32
# 10               Fertilizer_kg_ha        19.14       352.04             15
# ...

# %%
# Visual Outlier Analysis using Box Plots

for column in numeric_columns:
    plt.figure(figsize=(8, 4))

    sns.boxplot(x=df[column])

    plt.title(f"Box Plot for Outlier Detection: {column}")
    plt.xlabel(column)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 10. Bivariate Analysis
#
# Bivariate analysis is used to study the relationship between two variables. It helps identify patterns, associations, and differences between variables in the agricultural dataset.
#
# ### Types of Bivariate Analysis
#
# - Numerical vs Numerical Analysis
# - Categorical vs Numerical Analysis
# - Categorical vs Categorical Analysis
# - Correlation Analysis
# - Seasonal Comparison Analysis

# %%
# 1. Numerical vs Numerical Analysis
# Relationship between Rainfall and Crop Yield

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha"
)

plt.title("Relationship Between Rainfall and Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.tight_layout()
plt.show()

# %%
# 2. Categorical vs Numerical Analysis
# Comparison of Yield across Seasons

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha"
)

plt.title("Crop Yield Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.tight_layout()
plt.show()

# %%
# 3. Categorical vs Categorical Analysis
# Relationship between Season and Crop

season_crop = pd.crosstab(df["Season"], df["Crop"])

season_crop.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Crop Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Records")
plt.xticks(rotation=0)
plt.legend(title="Crop", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %%
# 4. Correlation Analysis

plt.figure(figsize=(14, 10))

correlation_matrix = df[numeric_columns].corr()

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Variables")

plt.tight_layout()
plt.show()

# %%
# 5. Seasonal Comparison Analysis
# Average Profit across Seasons

seasonal_profit = df.groupby("Season")["Profit_INR"].mean().reset_index()

plt.figure(figsize=(8, 5))

sns.barplot(
    data=seasonal_profit,
    x="Season",
    y="Profit_INR"
)

plt.title("Average Farm Profit Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 11. Multivariate Analysis
#
# Multivariate analysis is used to study the relationships among three or more variables simultaneously. It helps understand how environmental, operational, production, and economic factors interact and influence agricultural performance.
#
# This analysis can reveal complex patterns and relationships that may not be visible when studying only one or two variables.

# %%
# 1. Multivariate Analysis: Correlation Heatmap

plt.figure(figsize=(14, 10))

correlation_matrix = df[numeric_columns].corr()

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Variables")

plt.tight_layout()
plt.show()

# %%
# 2. Rainfall, Temperature and Crop Yield

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha",
    hue="Season",
    size="Avg_Temperature_C",
    sizes=(40, 200),
    alpha=0.8
)

plt.title("Rainfall, Temperature and Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes per Hectare)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %%
# 3. Multiple Factors Influencing Farm Profit

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Total_Cost_INR",
    y="Profit_INR",
    hue="Crop",
    size="Yield_Tonnes_Ha",
    sizes=(40, 200),
    alpha=0.8
)

plt.title("Relationship Between Cost, Yield and Farm Profit")
plt.xlabel("Total Cost (INR)")
plt.ylabel("Profit (INR)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %%
# Pair plot of environmental and performance metrics by season

selected_columns = [
    "Avg_Temperature_C",
    "Rainfall_mm",
    "Humidity_pct",
    "Yield_Tonnes_Ha",
    "Profit_INR",
    "Season"
]

sns.pairplot(
    df[selected_columns].dropna(),
    hue="Season",
    palette="viridis",
    plot_kws={"alpha": 0.6}
)

plt.suptitle(
    "Pair Plot of Environmental and Performance Metrics by Season",
    y=1.02
)

plt.tight_layout()
plt.show()

# %%
# 5. Seasonal Performance Comparison

seasonal_performance = df.groupby("Season")[
    ["Yield_Tonnes_Ha", "Profit_INR", "Rainfall_mm"]
].mean().reset_index()

seasonal_performance
# Out:
#    Season  Yield_Tonnes_Ha  Profit_INR  Rainfall_mm
# 0  Kharif             5.63  178,914.65       849.20
# 1    Rabi             5.04   87,689.47       437.62
# 2    Zaid             4.64  -24,804.82       304.65

# %%
# 6. Multivariate Seasonal Performance Plot

seasonal_performance_melted = seasonal_performance.melt(
    id_vars="Season",
    var_name="Variable",
    value_name="Average_Value"
)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=seasonal_performance_melted,
    x="Season",
    y="Average_Value",
    hue="Variable"
)

plt.title("Seasonal Comparison of Agricultural Performance")
plt.xlabel("Season")
plt.ylabel("Average Value")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 12. Seasonal Comparison
#
# Seasonal comparison is used to compare agricultural performance across different seasons. Summary tables and visualizations help identify differences in yield, production, profit, and water usage.
#
# The comparison focuses on meaningful measures that help answer the project problem rather than comparing every variable.

# %%
# General seasonal summary

season_metrics = df.groupby("Season").agg(
    Records=("Farm_ID", "count"),
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Total_Production=("Production_Tonnes", "sum"),
    Average_Profit=("Profit_INR", "mean"),
    Total_Profit=("Profit_INR", "sum"),
    Average_Water_Used=("Water_Used_m3", "mean")
).round(2)

season_metrics
# Out:
#         Records  Average_Yield  Total_Production  Average_Profit  \
# Season
# Kharif     1779           5.63         82,387.61      178,914.65
# Rabi       1627           5.04         67,498.88       87,689.47
# Zaid        594           4.64         23,098.35      -24,804.82
#
#         Total_Profit  Average_Water_Used
# Season
# Kharif     318289158            6,102.20
# Rabi       142670768            5,846.99
# Zaid       -14734066            6,419.89

# %%
# Seasonal comparison: Average Yield, Average Profit and Average Water Efficiency

season_metrics = df.groupby("Season").agg(
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Average_Profit=("Profit_INR", "mean"),
    Average_Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean")
).round(2)

season_metrics
# Out:
#         Average_Yield  Average_Profit  Average_Water_Efficiency
# Season
# Kharif           5.63      178,914.65                      5.89
# Rabi             5.04       87,689.47                      5.19
# Zaid             4.64      -24,804.82                      4.41

# %% [markdown]
# # 13. Key Insights
#
# ## Insight 1: Seasonal Record Distribution
#
# **Observation:** Kharif has the highest number of records with 1,779 observations, followed by Rabi with 1,627 observations and Zaid with 594 observations.
#
# **Evidence:** Season distribution bar chart, pie chart, and seasonal summary table.
#
# **Interpretation:** Kharif and Rabi are more represented in the dataset than Zaid.
#
# **Limitation:** The number of records does not necessarily represent the actual cultivated area or total agricultural activity.
#
# ---
#
# ## Insight 2: Seasonal Yield Performance
#
# **Observation:** Kharif has the highest average yield at 5.63 tonnes per hectare, followed by Rabi at 5.04 tonnes per hectare and Zaid at 4.64 tonnes per hectare.
#
# **Evidence:** Seasonal comparison table and seasonal yield box plot.
#
# **Interpretation:** Kharif shows the strongest average crop-yield performance among the three seasons in this dataset.
#
# **Limitation:** The difference may also be influenced by crop type, farming practices, and environmental conditions.
#
# ---
#
# ## Insight 3: Seasonal Profitability
#
# **Observation:** Kharif has the highest average profit of ₹178,914.65, while Zaid has a negative average profit of ₹−24,804.82.
#
# **Evidence:** Seasonal comparison table and profit comparison analysis.
#
# **Interpretation:** Farms recorded during Kharif were more profitable on average, whereas Zaid showed financial losses on average.
#
# **Limitation:** Average profit does not represent the profit of every farm and may be affected by extreme values.
#
# ---
#
# ## Insight 4: Seasonal Water Efficiency
#
# **Observation:** Kharif has the highest average water-use efficiency at 5.89 tonnes per 1,000 m³, followed by Rabi at 5.19 and Zaid at 4.41.
#
# **Evidence:** Seasonal water-efficiency comparison table.
#
# **Interpretation:** Kharif produced more crop output relative to water used, on average, compared with Rabi and Zaid.
#
# **Limitation:** Water efficiency may depend on crop type, irrigation method, rainfall, and farm conditions.
#
# ---
#
# ## Insight 5: Seasonal Water Usage
#
# **Observation:** Zaid has the highest average water usage at 6,419.89 m³, while Rabi has the lowest average water usage at 5,846.99 m³.
#
# **Evidence:** Seasonal summary table.
#
# **Interpretation:** Zaid farms used more water on average, which may be associated with differences in seasonal rainfall and irrigation requirements.
#
# **Limitation:** Higher water usage does not automatically indicate inefficient farming because farm size and crop requirements may differ.
#
# ---
#
# ## Insight 6: Variation in Crop Yield
#
# **Observation:** The mean crop yield is 5.24 tonnes per hectare, while the median is 1.74 tonnes per hectare.
#
# **Evidence:** Descriptive statistical summary.
#
# **Interpretation:** The difference between the mean and median suggests that some high-yield observations increase the average yield.
#
# **Limitation:** This difference alone does not identify the exact reason for the high values.
#
# ---
#
# ## Insight 7: Outliers in Production and Profit
#
# **Observation:** The IQR analysis identified 333 potential outliers in total production, 240 in revenue, and 404 in profit.
#
# **Evidence:** IQR-based outlier summary and box plots.
#
# **Interpretation:** Some farms have unusually high or low production, revenue, or profit values that may represent exceptional performance, large farms, or unusual economic conditions.
#
# **Limitation:** These values should not be deleted automatically without checking whether they are genuine observations.
#
# ---
#
# ## Insight 8: Outliers in Water Efficiency
#
# **Observation:** The IQR method identified 322 potential outliers in water-use efficiency.
#
# **Evidence:** IQR-based outlier summary and water-efficiency box plot.
#
# **Interpretation:** Water efficiency varies considerably across farms, and some farms have unusually high or low output relative to water usage.
#
# **Limitation:** Extreme water-efficiency values may be influenced by crop type, farm size, irrigation method, or measurement variation.

# %% [markdown]
# # 14. Recommendations
#
# 1. Farmers should consider seasonal conditions when selecting crops and planning agricultural activities.
#
# 2. Crops showing higher average yield may be considered for cultivation, provided that their production costs and resource requirements are also suitable.
#
# 3. Water-efficient crops and irrigation practices should be encouraged to reduce unnecessary water consumption.
#
# 4. Farmers should compare expected profit, production cost, and market price before selecting a crop.
#
# 5. Further investigation should be conducted for extreme values detected during outlier analysis to identify possible data-entry errors or unusual farming conditions.
#
# 6. Agricultural planning should consider rainfall, temperature, and humidity because environmental conditions may influence crop performance.
#
# 7. More balanced data collection across seasons, crops, and states would improve the reliability of comparisons.
#
# 8. Future analysis can include predictive models to estimate crop yield and profit using environmental and operational variables.

# %% [markdown]
# # 15. Conclusion
#
# The Seasonal Agriculture Performance Analysis helped examine agricultural data across different seasons, crops, and locations. Descriptive statistics, univariate analysis, bivariate analysis, multivariate analysis, seasonal comparisons, and outlier analysis were used to understand the dataset.
#
# The analysis highlighted how environmental factors such as rainfall, temperature, and humidity may be associated with crop yield. It also helped compare crop profitability and water-use efficiency. The findings can support better agricultural planning and resource management.
#
# However, the results are based only on the available dataset. The analysis shows relationships and patterns but does not prove direct cause-and-effect relationships. Further research using larger and more balanced datasets can improve the reliability of the findings.

# %% [markdown]
# # 16. Project Summary
#
# This project analyzed seasonal agricultural performance using environmental, operational, production, and economic variables. The dataset was examined through data cleaning, feature review, descriptive statistics, visualizations, outlier analysis, and comparisons across seasons and crops.
#
# The main focus was to understand differences in crop yield, profit, and water-use efficiency and to identify patterns that may help improve agricultural decision-making. The analysis provides a foundation for future predictive analysis and data-driven agricultural planning.
